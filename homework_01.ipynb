# %%
print("Меня зовут Шахзод, и я готов страдать на курсе!")
# Out:
# Меня зовут Шахзод, и я готов страдать на курсе!

# %% [markdown]
# # Мое имя

# %% [markdown]
# **Меня зовут Шахзод и я учусь в магистратуре в котором изучаем такие предметь как:**
# - ИТОД
# - Python
# - Практика моделирования

# %%
print(77 % 2)
# Out:
# 1

# %%
print(22 % 2 == 0)
# Out:
# True

# %%
print(86**7)
# Out:
# 34792782221696

# %%
import math
print(math.sqrt(3686400))
# Out:
# 1920.0
